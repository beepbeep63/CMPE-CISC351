# %%
# Import the necessary packages
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
import missingno as msno
from scipy.stats import skew, norm
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sklearn

# %%
df = pd.read_csv("/content/Tenrec/QB-video.csv")
df.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    user_id  item_id  click  follow  like  share video_category  \
# 0  3502303  1375832      0       0     0      0              1
# 1  3502303    32277      0       0     0      0              0
# 2  3502303  1425848      0       0     0      0              0
# 3  3502303  1480204      0       0     0      0              0
# 4  3502303  1406570      0       0     0      0              0
#
#    watching_times  gender  age
# 0               1       0    0
# 1               1       0    0
# 2               1       0    0
# 3               1       0    0
# 4               1       0    0

# %%
# Shape of the data
df.shape

# Data information
df.info()

# Check the missing values
print("\nMissing Values: ")
df.isna().sum()

df = df[df.columns.drop(list(df.filter(regex='N')))]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2442299 entries, 0 to 2442298
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   user_id         int64
#  1   item_id         int64
#  2   click           int64
#  3   follow          int64
#  4   like            int64
#  5   share           int64
#  6   video_category  object
#  7   watching_times  int64
#  8   gender          int64
#  9   age             int64
# dtypes: int64(9), object(1)
# memory usage: 186.3+ MB
#
# Missing Values:

# %%
sns.barplot(data=df, x='gender', y='like')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='like'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(df.loc[:, 'like'].mean())
# Out:
# 0.008470297862792393

# %%
fig, ax = plt.subplots(figsize=(20, 10))
corr = df.corr()[['gender']]
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv("/content/Tenrec/sbr_data_1M.csv")
df.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    user_id  item_id  click  follow  like  share video_category  \
# 0        1        1      1       0     0      0              1
# 1        1        2      1       0     0      0              1
# 2        1        3      1       0     0      0              0
# 3        1    80936      1       0     0      0              1
# 4        1      781      1       0     0      0              1
#
#    watching_times  gender  age
# 0               1       1    4
# 1               1       1    4
# 2               1       1    4
# 3               1       1    4
# 4               1       1    4

# %%
sns.barplot(data=df, x='gender', y='like')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='like'>

# %%
fig, ax = plt.subplots(figsize=(20, 10))
corr = df.corr()[['gender']]
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
